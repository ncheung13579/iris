# %% [markdown]
# # Notebook 11: Multi-Layer SAE Analysis (Experiment A1)
#
# **Purpose:** Train SAEs on three different GPT-2 layers (0, 6, 11) and
# compare detection performance + evasion resistance across layers.
#
# **Hypothesis:** Deeper layers encode more abstract, task-relevant features.
# Layer 0 captures surface-level patterns. Layer 6 (middle) may have the
# best balance of abstraction and specificity. Layer 11 (final) may
# over-specialize on next-token prediction.
#
# **Prerequisites:** Run notebook 10 first (expanded dataset + activations).
#
# **Runtime:** Colab GPU (T4), ~30 minutes (3 SAE training runs).

# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install -r /content/drive/MyDrive/iris/requirements.txt -q
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.insert(0, '/content/drive/MyDrive/iris')

import json
import numpy as np
import torch
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import StratifiedKFold

from src.utils.helpers import set_seed, get_device
set_seed(42)
device = get_device()

DRIVE_ROOT = Path('/content/drive/MyDrive/iris')
# Out:
# Using GPU: Tesla T4

# %%
# Load activations — use expanded if available, otherwise original
expanded_path = DRIVE_ROOT / 'checkpoints' / 'expanded_activations.npz'
original_path = DRIVE_ROOT / 'checkpoints' / 'j2_activations.npz'

if expanded_path.exists():
    print('Loading expanded activations...')
    act_data = np.load(str(expanded_path))
else:
    print('Loading original activations (expanded not found)...')
    act_data = np.load(str(original_path))

labels = act_data['labels']
print(f'Loaded {len(labels)} examples')
print(f'Label distribution: {dict(zip(*np.unique(labels, return_counts=True)))}')
# Out:
# Loading expanded activations...
# Loaded 1000 examples
# Label distribution: {0: 500, 1: 500}

# %% [markdown]
# ## Step 1: Train SAEs on Layers 0, 6, and 11
#
# We use the same architecture (8x expansion, lambda=1e-4) across all layers
# so the only variable is *where* in the transformer we extract activations.
#
# - **Layer 0:** Immediately after the embedding + positional encoding.
#   Features here reflect surface-level token patterns.
# - **Layer 6:** Middle of the network. Attention has had 6 layers to
#   compose token-level signals into phrase/sentence-level representations.
# - **Layer 11:** Final layer, just before the unembedding. Features here
#   are optimized for next-token prediction and may be the most abstract.

# %%
from src.sae.training import train_sae

TARGET_LAYERS = [0, 6, 11]
EXPANSION_FACTOR = 8
SPARSITY_COEFF = 1e-4
EPOCHS = 20
D_INPUT = 768

trained_saes = {}

for layer in TARGET_LAYERS:
    print(f'\n{"="*60}')
    print(f'Training SAE on Layer {layer}')
    print(f'{"="*60}')

    layer_acts = torch.from_numpy(act_data[f'layer_{layer}'])

    result = train_sae(
        activations=layer_acts,
        d_input=D_INPUT,
        expansion_factor=EXPANSION_FACTOR,
        sparsity_coeff=SPARSITY_COEFF,
        epochs=EPOCHS,
        device=device,
        seed=42,
        checkpoint_dir=DRIVE_ROOT / 'checkpoints' / 'multi_layer',
    )

    trained_saes[layer] = result
    print(f'Layer {layer} final MSE: {result["final_metrics"]["final_mse_loss"]:.6f}')
    print(f'Layer {layer} final sparsity: {result["final_metrics"]["final_mean_sparsity"]:.3%}')
# Out:
# ============================================================
# Training SAE on Layer 0
# ============================================================
# Dataset: 1000 activation vectors of dim 768
# Input variance (mean per-element MSE from mean): 0.207457
# J2 target — reconstruction MSE must be < 0.020746 (= 0.1 × input variance)
#
#   Epoch 1/20  Batch 4/4  loss=2.562307  mse=2.561352  l1=0.954770  active=48.903%
# [Epoch 1/20]  loss=5.922540  mse=5.921567  l1=0.973323  active=49.244%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 2/20  Batch 4/4  loss=2.669145  mse=2.668249  l1=0.896673  active=46.410%
# [Epoch 2/20]  loss=3.089436  mse=3.088514  l1=0.921988  active=47.486%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 3/20  Batch 4/4  loss=1.297494  mse=1.296661  l1=0.832615  active=43.816%
# [Epoch 3/20]  loss=1.639786  mse=1.638930  l1=0.855099  active=44.735%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 4/20  Batch 4/4  loss=1.112621  mse=1.111834  l1=0.786536  active=42.081%
# [Epoch 4/20]  loss=1.097759  mse=1.096959  l1=0.799801  active=42.645%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 5/20  Batch 4/4  loss=0.770936  mse=0.770185  l1=0.751354  active=40.741%
# [Epoch 5/20]  loss=0.850941  mse=0.850180  l1=0.760631  active=41.158%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 6/20  Batch 4/4  loss=0.528906  mse=0.528174  l1=0.732669  active=40.050%
# [Epoch 6/20]  loss=0.597141  mse=0.596404  l1=0.737026  active=40.272%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 7/20  Batch 4/4  loss=0.456612  mse=0.455890  l1=0.721781  active=39.709%
# [Epoch 7/20]  loss=0.466243  mse=0.465520  l1=0.723256  active=39.791%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 8/20  Batch 4/4  loss=0.361035  mse=0.360328  l1=0.707780  active=39.197%
# [Epoch 8/20]  loss=0.367449  mse=0.366738  l1=0.711460  active=39.333%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 9/20  Batch 4/4  loss=0.274759  mse=0.274064  l1=0.695103  active=38.680%
# [Epoch 9/20]  loss=0.297958  mse=0.297259  l1=0.699347  active=38.873%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 10/20  Batch 4/4  loss=0.242524  mse=0.241836  l1=0.688308  active=38.450%
# [Epoch 10/20]  loss=0.251407  mse=0.250718  l1=0.688833  active=38.519%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 11/20  Batch 4/4  loss=0.203469  mse=0.202790  l1=0.679381  active=38.208%
# [Epoch 11/20]  loss=0.204498  mse=0.203816  l1=0.681673  active=38.275%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 12/20  Batch 4/4  loss=0.171826  mse=0.171149  l1=0.677144  active=38.134%
# [Epoch 12/20]  loss=0.181422  mse=0.180745  l1=0.677697  active=38.143%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 13/20  Batch 4/4  loss=0.137195  mse=0.136523  l1=0.671660  active=37.982%
# [Epoch 13/20]  loss=0.156556  mse=0.155880  l1=0.675152  active=38.077%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 14/20  Batch 4/4  loss=0.140782  mse=0.140103  l1=0.678574  active=38.088%
# [Epoch 14/20]  loss=0.137386  mse=0.136713  l1=0.673446  active=38.021%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 15/20  Batch 4/4  loss=0.118309  mse=0.117638  l1=0.671144  active=37.937%
# [Epoch 15/20]  loss=0.125134  mse=0.124462  l1=0.671544  active=37.959%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 16/20  Batch 4/4  loss=0.106671  mse=0.106002  l1=0.669263  active=37.928%
# [Epoch 16/20]  loss=0.112345  mse=0.111675  l1=0.669954  active=37.926%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 17/20  Batch 4/4  loss=0.097903  mse=0.097239  l1=0.664162  active=37.829%
# [Epoch 17/20]  loss=0.103443  mse=0.102774  l1=0.668610  active=37.913%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 18/20  Batch 4/4  loss=0.093811  mse=0.093144  l1=0.666448  active=37.862%
# [Epoch 18/20]  loss=0.096004  mse=0.095336  l1=0.667838  active=37.866%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 19/20  Batch 4/4  loss=0.079295  mse=0.078631  l1=0.663604  active=37.685%
# [Epoch 19/20]  loss=0.089006  mse=0.088338  l1=0.667456  active=37.843%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 20/20  Batch 4/4  loss=0.078005  mse=0.077341  l1=0.663987  active=37.750%
# [Epoch 20/20]  loss=0.084007  mse=0.083340  l1=0.667253  active=37.836%  J2-recon=FAIL  J2-sparse=FAIL
#
# Checkpoint saved: /content/drive/MyDrive/iris/checkpoints/multi_layer/sae_d6144_lambda1e-04.pt (113.3 MB)
# Layer 0 final MSE: 0.083340
# Layer 0 final sparsity: 37.836%
#
# ============================================================
# Training SAE on Layer 6
# ============================================================
# Dataset: 1000 activation vectors of dim 768
# Input variance (mean per-element MSE from mean): 0.992694
# J2 target — reconstruction MSE must be < 0.099269 (= 0.1 × input variance)
#
#   Epoch 1/20  Batch 4/4  loss=10.023643  mse=10.022118  l1=1.524699  active=48.274%
# [Epoch 1/20]  loss=17.218760  mse=17.217200  l1=1.560476  active=48.982%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 2/20  Batch 4/4  loss=8.491199  mse=8.489833  l1=1.366461  active=44.031%
# [Epoch 2/20]  loss=10.638757  mse=10.637327  l1=1.430421  active=45.763%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 3/20  Batch 4/4  loss=5.083145  mse=5.081896  l1=1.248836  active=40.493%
# [Epoch 3/20]  loss=5.736276  mse=5.734986  l1=1.290092  active=41.711%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 4/20  Batch 4/4  loss=4.662332  mse=4.661160  l1=1.171803  active=38.275%
# [Epoch 4/20]  loss=4.670933  mse=4.669740  l1=1.193545  active=38.952%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 5/20  Batch 4/4  loss=3.257511  mse=3.256409  l1=1.102799  active=36.677%
# [Epoch 5/20]  loss=3.611521  mse=3.610397  l1=1.123620  active=37.151%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 6/20  Batch 4/4  loss=2.727489  mse=2.726414  l1=1.074723  active=35.694%
# [Epoch 6/20]  loss=2.856148  mse=2.855071  l1=1.076668  active=35.987%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 7/20  Batch 4/4  loss=2.406281  mse=2.405237  l1=1.043610  active=35.008%
# [Epoch 7/20]  loss=2.417130  mse=2.416085  l1=1.045175  active=35.133%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 8/20  Batch 4/4  loss=1.904739  mse=1.903726  l1=1.012660  active=34.234%
# [Epoch 8/20]  loss=2.023188  mse=2.022169  l1=1.018359  active=34.396%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 9/20  Batch 4/4  loss=1.672063  mse=1.671077  l1=0.985457  active=33.518%
# [Epoch 9/20]  loss=1.771585  mse=1.770592  l1=0.993497  active=33.773%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 10/20  Batch 4/4  loss=1.577676  mse=1.576708  l1=0.967490  active=33.195%
# [Epoch 10/20]  loss=1.569020  mse=1.568047  l1=0.972410  active=33.286%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 11/20  Batch 4/4  loss=1.336167  mse=1.335210  l1=0.957430  active=32.811%
# [Epoch 11/20]  loss=1.394790  mse=1.393833  l1=0.957451  active=32.910%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 12/20  Batch 4/4  loss=1.184196  mse=1.183250  l1=0.945982  active=32.520%
# [Epoch 12/20]  loss=1.277380  mse=1.276432  l1=0.948155  active=32.653%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 13/20  Batch 4/4  loss=1.146586  mse=1.145652  l1=0.934397  active=32.324%
# [Epoch 13/20]  loss=1.167071  mse=1.166129  l1=0.941787  active=32.474%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 14/20  Batch 4/4  loss=0.983978  mse=0.983032  l1=0.946152  active=32.317%
# [Epoch 14/20]  loss=1.079826  mse=1.078889  l1=0.936416  active=32.305%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 15/20  Batch 4/4  loss=0.975259  mse=0.974332  l1=0.926572  active=32.003%
# [Epoch 15/20]  loss=1.013994  mse=1.013063  l1=0.930180  active=32.112%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 16/20  Batch 4/4  loss=0.926488  mse=0.925561  l1=0.927494  active=31.882%
# [Epoch 16/20]  loss=0.950703  mse=0.949778  l1=0.924694  active=31.941%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 17/20  Batch 4/4  loss=0.894368  mse=0.893458  l1=0.910317  active=31.582%
# [Epoch 17/20]  loss=0.902248  mse=0.901329  l1=0.919816  active=31.790%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 18/20  Batch 4/4  loss=0.848397  mse=0.847478  l1=0.918992  active=31.629%
# [Epoch 18/20]  loss=0.856167  mse=0.855250  l1=0.917036  active=31.676%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 19/20  Batch 4/4  loss=0.800787  mse=0.799889  l1=0.898732  active=31.218%
# [Epoch 19/20]  loss=0.817337  mse=0.816423  l1=0.914240  active=31.573%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 20/20  Batch 4/4  loss=0.783703  mse=0.782797  l1=0.906162  active=31.280%
# [Epoch 20/20]  loss=0.783353  mse=0.782442  l1=0.911789  active=31.476%  J2-recon=FAIL  J2-sparse=FAIL
#
# Checkpoint saved: /content/drive/MyDrive/iris/checkpoints/multi_layer/sae_d6144_lambda1e-04.pt (113.3 MB)
# Layer 6 final MSE: 0.782442
# Layer 6 final sparsity: 31.476%
#
# ============================================================
# Training SAE on Layer 11
# ============================================================
# Dataset: 1000 activation vectors of dim 768
# Input variance (mean per-element MSE from mean): 22.450058
# J2 target — reconstruction MSE must be < 2.245006 (= 0.1 × input variance)
#
#   Epoch 1/20  Batch 4/4  loss=334.044037  mse=334.032776  l1=11.270951  active=49.705%
# [Epoch 1/20]  loss=805.657555  mse=805.646103  l1=11.435550  active=49.959%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 2/20  Batch 4/4  loss=422.815033  mse=422.804138  l1=10.895431  active=47.780%
# [Epoch 2/20]  loss=448.045418  mse=448.034393  l1=11.022174  active=48.629%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 3/20  Batch 4/4  loss=242.761276  mse=242.751083  l1=10.188396  active=45.456%
# [Epoch 3/20]  loss=283.733002  mse=283.722553  l1=10.446808  active=46.288%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 4/20  Batch 4/4  loss=183.887283  mse=183.877487  l1=9.796432  active=43.751%
# [Epoch 4/20]  loss=201.294277  mse=201.284367  l1=9.906687  active=44.278%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 5/20  Batch 4/4  loss=143.302277  mse=143.292938  l1=9.334034  active=42.499%
# [Epoch 5/20]  loss=150.292866  mse=150.283363  l1=9.501298  active=42.894%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 6/20  Batch 4/4  loss=120.190231  mse=120.180992  l1=9.235558  active=41.914%
# [Epoch 6/20]  loss=131.845188  mse=131.835932  l1=9.254679  active=42.100%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 7/20  Batch 4/4  loss=94.998215  mse=94.989166  l1=9.046069  active=41.515%
# [Epoch 7/20]  loss=101.411253  mse=101.402149  l1=9.103680  active=41.617%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 8/20  Batch 4/4  loss=83.737640  mse=83.728653  l1=8.987683  active=41.126%
# [Epoch 8/20]  loss=88.065647  mse=88.056644  l1=9.003275  active=41.274%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 9/20  Batch 4/4  loss=75.809784  mse=75.800949  l1=8.835036  active=40.782%
# [Epoch 9/20]  loss=79.349937  mse=79.341028  l1=8.910057  active=40.938%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 10/20  Batch 4/4  loss=64.844215  mse=64.835480  l1=8.738646  active=40.426%
# [Epoch 10/20]  loss=70.094259  mse=70.085451  l1=8.809442  active=40.553%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 11/20  Batch 4/4  loss=63.166073  mse=63.157360  l1=8.714315  active=40.136%
# [Epoch 11/20]  loss=63.749955  mse=63.741235  l1=8.720465  active=40.237%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 12/20  Batch 4/4  loss=57.366634  mse=57.357933  l1=8.699870  active=39.990%
# [Epoch 12/20]  loss=59.455784  mse=59.447124  l1=8.660175  active=40.045%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 13/20  Batch 4/4  loss=54.229259  mse=54.220646  l1=8.614946  active=39.950%
# [Epoch 13/20]  loss=55.318225  mse=55.309598  l1=8.626195  active=39.959%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 14/20  Batch 4/4  loss=53.264286  mse=53.255634  l1=8.651486  active=40.038%
# [Epoch 14/20]  loss=51.772852  mse=51.764241  l1=8.610929  active=39.928%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 15/20  Batch 4/4  loss=48.867031  mse=48.858486  l1=8.546550  active=39.911%
# [Epoch 15/20]  loss=49.095164  mse=49.086571  l1=8.594268  active=39.903%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 16/20  Batch 4/4  loss=48.693089  mse=48.684460  l1=8.628613  active=39.913%
# [Epoch 16/20]  loss=46.443333  mse=46.434756  l1=8.576367  active=39.887%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 17/20  Batch 4/4  loss=44.015884  mse=44.007359  l1=8.526450  active=39.788%
# [Epoch 17/20]  loss=44.156871  mse=44.148317  l1=8.552974  active=39.855%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 18/20  Batch 4/4  loss=41.899834  mse=41.891293  l1=8.542243  active=39.776%
# [Epoch 18/20]  loss=42.070785  mse=42.062244  l1=8.539807  active=39.842%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 19/20  Batch 4/4  loss=38.410442  mse=38.401917  l1=8.524950  active=39.744%
# [Epoch 19/20]  loss=40.070525  mse=40.061990  l1=8.534206  active=39.860%  J2-recon=FAIL  J2-sparse=FAIL
#
#   Epoch 20/20  Batch 4/4  loss=37.026848  mse=37.018299  l1=8.550403  active=39.843%
# [Epoch 20/20]  loss=38.309918  mse=38.301389  l1=8.530041  active=39.872%  J2-recon=FAIL  J2-sparse=FAIL
#
# Checkpoint saved: /content/drive/MyDrive/iris/checkpoints/multi_layer/sae_d6144_lambda1e-04.pt (113.3 MB)
# Layer 11 final MSE: 38.301389
# Layer 11 final sparsity: 39.872%

# %% [markdown]
# ## Step 2: Compute Features & Sensitivity for Each Layer

# %%
from src.analysis.features import compute_feature_activations, compute_sensitivity_scores

layer_features = {}
layer_sensitivity = {}

for layer in TARGET_LAYERS:
    print(f'\nComputing features for layer {layer}...')
    sae_model = trained_saes[layer]['model']
    layer_acts = act_data[f'layer_{layer}']

    features = compute_feature_activations(sae_model, layer_acts, device=device)
    sensitivity = compute_sensitivity_scores(features, labels)

    layer_features[layer] = features
    layer_sensitivity[layer] = sensitivity

    # Save
    np.save(str(DRIVE_ROOT / 'checkpoints' / 'multi_layer' / f'features_layer{layer}.npy'), features)
    np.save(str(DRIVE_ROOT / 'checkpoints' / 'multi_layer' / f'sensitivity_layer{layer}.npy'), sensitivity)
# Out:
# Computing features for layer 0...
# Sensitivity scores computed for 6144 features:
#   Injection-associated (positive): 3056
#   Normal-associated (negative):    2544
#   Neutral (zero):                  544
#   Max sensitivity:  0.4258
#   Min sensitivity:  -0.3949
#   Mean |sensitivity|: 0.0446
#
# Computing features for layer 6...
# Sensitivity scores computed for 6144 features:
#   Injection-associated (positive): 3004
#   Normal-associated (negative):    2995
#   Neutral (zero):                  145
#   Max sensitivity:  1.2332
#   Min sensitivity:  -1.1678
#   Mean |sensitivity|: 0.1176
#
# Computing features for layer 11...
# Sensitivity scores computed for 6144 features:
#   Injection-associated (positive): 1683
#   Normal-associated (negative):    3342
#   Neutral (zero):                  1119
#   Max sensitivity:  5.3825
#   Min sensitivity:  -5.7202
#   Mean |sensitivity|: 0.6129

# %% [markdown]
# ## Step 3: Cross-Validated Detection Comparison Across Layers
#
# For each layer, run 5-fold CV with the SAE feature detector.
# This tells us which layer's SAE features are most useful for detection.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, roc_auc_score

N_FOLDS = 5
skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=42)

layer_cv_results = {}

for layer in TARGET_LAYERS:
    features = layer_features[layer]
    fold_f1s = []
    fold_aucs = []

    for fold_idx, (train_idx, test_idx) in enumerate(skf.split(features, labels)):
        clf = LogisticRegression(max_iter=1000, random_state=42)
        clf.fit(features[train_idx], labels[train_idx])

        y_pred = clf.predict(features[test_idx])
        y_prob = clf.predict_proba(features[test_idx])[:, 1]

        fold_f1s.append(f1_score(labels[test_idx], y_pred))
        fold_aucs.append(roc_auc_score(labels[test_idx], y_prob))

    layer_cv_results[layer] = {
        'f1_mean': float(np.mean(fold_f1s)),
        'f1_std': float(np.std(fold_f1s, ddof=1)),
        'auc_mean': float(np.mean(fold_aucs)),
        'auc_std': float(np.std(fold_aucs, ddof=1)),
        'f1_per_fold': [float(x) for x in fold_f1s],
        'auc_per_fold': [float(x) for x in fold_aucs],
    }
    print(f'Layer {layer}: F1={np.mean(fold_f1s):.3f}+/-{np.std(fold_f1s, ddof=1):.3f}, '
          f'AUC={np.mean(fold_aucs):.3f}+/-{np.std(fold_aucs, ddof=1):.3f}')
# Out:
# Layer 0: F1=0.924+/-0.023, AUC=0.956+/-0.016
# Layer 6: F1=0.954+/-0.011, AUC=0.979+/-0.007
# Layer 11: F1=0.950+/-0.023, AUC=0.989+/-0.007

# %% [markdown]
# ## Step 4: Sensitivity Distribution Comparison
#
# Compare how injection-sensitive each layer's features are.
# A wider distribution = the SAE found more discriminative features.

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4), sharey=True)
colors = ['#0072B2', '#D55E00', '#009E73']

for ax, layer, color in zip(axes, TARGET_LAYERS, colors):
    sens = layer_sensitivity[layer]
    ax.hist(sens, bins=80, color=color, alpha=0.8, edgecolor='white')
    ax.axvline(x=0, color='black', linestyle='-', linewidth=0.8)
    ax.set_xlabel('Sensitivity Score')
    ax.set_title(f'Layer {layer}')

    # Stats
    n_pos = (sens > 0).sum()
    n_neg = (sens < 0).sum()
    max_abs = np.abs(sens).max()
    ax.text(0.02, 0.95, f'+: {n_pos}\n-: {n_neg}\nmax|s|: {max_abs:.3f}',
            transform=ax.transAxes, va='top', fontsize=9,
            bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

axes[0].set_ylabel('Number of Features')
fig.suptitle('Injection-Sensitivity Distribution by Layer', fontsize=14)
plt.tight_layout()

save_path = DRIVE_ROOT / 'results' / 'figures' / 'a1_sensitivity_by_layer.png'
save_path.parent.mkdir(parents=True, exist_ok=True)
fig.savefig(str(save_path), dpi=200, bbox_inches='tight')
plt.show()
print(f'Saved to {save_path}')
# Out:
# Saved to /content/drive/MyDrive/iris/results/figures/a1_sensitivity_by_layer.png

# %% [markdown]
# ## Step 5: Layer Comparison Bar Chart

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
colors = ['#0072B2', '#D55E00', '#009E73']
layer_labels = [f'Layer {l}' for l in TARGET_LAYERS]
x = np.arange(len(TARGET_LAYERS))

for ax, metric, title in zip(axes, ['f1', 'auc'], ['F1 Score', 'ROC AUC']):
    means = [layer_cv_results[l][f'{metric}_mean'] for l in TARGET_LAYERS]
    stds = [layer_cv_results[l][f'{metric}_std'] for l in TARGET_LAYERS]

    bars = ax.bar(x, means, yerr=stds, capsize=5, color=colors, alpha=0.85)
    for bar, mean, std in zip(bars, means, stds):
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + std + 0.005,
                f'{mean:.3f}', ha='center', va='bottom', fontsize=11, fontweight='bold')

    ax.set_xticks(x)
    ax.set_xticklabels(layer_labels, fontsize=11)
    ax.set_ylabel(title, fontsize=11)
    ax.set_title(f'{title} by Layer (5-fold CV)', fontsize=12)
    ax.set_ylim(0.8, 1.05)

plt.tight_layout()
save_path = DRIVE_ROOT / 'results' / 'figures' / 'a1_layer_comparison.png'
fig.savefig(str(save_path), dpi=200, bbox_inches='tight')
plt.show()
print(f'Saved to {save_path}')
# Out:
# Saved to /content/drive/MyDrive/iris/results/figures/a1_layer_comparison.png

# %%
# Save all A1 results
a1_results = {
    'experiment': 'A1',
    'layers': TARGET_LAYERS,
    'n_folds': N_FOLDS,
    'n_samples': len(labels),
    'sae_config': {
        'expansion_factor': EXPANSION_FACTOR,
        'sparsity_coeff': SPARSITY_COEFF,
        'epochs': EPOCHS,
    },
    'results': {str(k): v for k, v in layer_cv_results.items()},
    'training_metrics': {
        str(layer): trained_saes[layer]['final_metrics']
        for layer in TARGET_LAYERS
    },
}

results_path = DRIVE_ROOT / 'results' / 'metrics' / 'a1_multi_layer.json'
results_path.write_text(json.dumps(a1_results, indent=2))
print(f'Saved A1 results to {results_path}')

# Identify best layer
best_layer = max(TARGET_LAYERS, key=lambda l: layer_cv_results[l]['f1_mean'])
print(f'\nBest layer for detection: Layer {best_layer} '
      f'(F1={layer_cv_results[best_layer]["f1_mean"]:.3f})')
print('Use this layer for causal intervention experiments (C5).')
# Out:
# Saved A1 results to /content/drive/MyDrive/iris/results/metrics/a1_multi_layer.json
#
# Best layer for detection: Layer 6 (F1=0.954)
# Use this layer for causal intervention experiments (C5).
